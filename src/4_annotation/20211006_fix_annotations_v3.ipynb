# %% [markdown]
# # Fix annotations - V3

# %%
import os,sys
import numpy as np 
import pandas as pd
import scanpy as sc
import scanpy.external as sce
import anndata
import scipy
import matplotlib.pyplot as plt

# %%
import re

# %%
import scvelo as scv
import seaborn as sns

# %%
data_dir = '/nfs/team205/ed6/data/Fetal_immune/'
timestamp = '20210429'
marker_genes_dir = "/home/jovyan/mount/gdrive/Pan_fetal/significant_genes/marker genes/"

# %%
figdir = "/home/jovyan/mount/gdrive/Pan_fetal/Updates_and_presentations/figures/annotationsV2/"
if os.path.exists(figdir):
    sc.settings.figdir = figdir
    scv.settings.figdir = figdir
else:
    os.mkdir(figdir)
    sc.settings.figdir = figdir
    scv.settings.figdir = figdir

# %%
def _load_split(split, min_n_cells = 50):
    spl_adata = sc.read_h5ad(data_dir + 'PAN.A01.v01.entire_data_normalised_log.{t}.{s}.embedding.h5ad'.format(t=timestamp, s=split))
    spl_adata = spl_adata[~spl_adata.obs_names.isin(mat_barcodes)]
    
    ## Save annotations for split
    spl_adata.obs["anno_lvl_2_final_clean"] = anno_obs.loc[spl_adata.obs_names]["anno_lvl_2_final_clean"].astype("str")

    ## Label as OTHER cell labels that appear in less than 50 cells
    small_labels = spl_adata.obs["anno_lvl_2_final_clean"].value_counts()[spl_adata.obs["anno_lvl_2_final_clean"].value_counts() < min_n_cells].index
    spl_adata.obs.loc[spl_adata.obs["anno_lvl_2_final_clean"].isin(small_labels), "anno_lvl_2_final_clean"] = "OTHER"
    spl_adata.obs.loc[spl_adata.obs["anno_lvl_2_final_clean"]=="LOW_Q_INCONSISTENT", "anno_lvl_2_final_clean"] = "OTHER"
    return(spl_adata)

def _plot_marker_dotplot(spl_adata, mark_split, 
                         labels_order=None, 
                         gene_labels_order=None, 
                         unique_genes=False,
                         **kwargs):
    markers_df = all_markers_df[all_markers_df["split"].isin(mark_split)]
    markers_df = markers_df[markers_df.gene.isin(spl_adata.var_names)]
    # markers_df = markers_df.sort_values('anno_lvl_2')
    if gene_labels_order is None:
        gene_labels_order = markers_df.anno_lvl_2.unique().tolist()

    markers_df= markers_df[markers_df.anno_lvl_2.isin(gene_labels_order)]
    markers_dict = {g: d['gene'].values.tolist() for g, d in markers_df.groupby('anno_lvl_2')}
    markers_dict = {k: markers_dict[k] for k in gene_labels_order}
    
    if labels_order is None:
        labels_order = gene_labels_order
    
    keep_labels = [x for x in labels_order if x in spl_adata.obs["anno_lvl_2_final_clean"].values]
    
    if unique_genes:
        markers_ls_2 = sum(markers_dict.values(), [])
        markers_ls_ixs = np.unique(markers_ls_2, return_index=True)[1]
        markers_dict = [markers_ls_2[index] for index in sorted(markers_ls_ixs)]
    
    sc.pl.dotplot(spl_adata[spl_adata.obs["anno_lvl_2_final_clean"].isin(keep_labels)], 
                      markers_dict, 
                      groupby="anno_lvl_2_final_clean", 
                      categories_order=keep_labels, **kwargs)
        
        
def _plot_split_embedding(spl_adata, split, **kwargs):
    sns.set_context("talk")
    scv.pl.umap(spl_adata, color="anno_lvl_2_final_clean", legend_loc="on data", 
                size=2, legend_fontoutline=3,
                title=split, **kwargs)

# %%
def _save_plot_markers_embedding(spl_adata, mark_split, ncols=4, gene_labels_order = None):
    markers_df = all_markers_df[all_markers_df["split"].isin(mark_split)]
    markers_df = markers_df[markers_df.gene.isin(spl_adata.var_names)]
    # markers_df = markers_df.sort_values('anno_lvl_2')
    if gene_labels_order is None:
        gene_labels_order = markers_df.anno_lvl_2.unique().tolist()
    emb_figdir = "embedding_markers_{s}/".format(s=''.join(mark_split))
    if not os.path.exists(figdir + emb_figdir):
        os.mkdir(figdir + emb_figdir)
    scv.settings.figdir = figdir + emb_figdir

    for label in markers_df.anno_lvl_2.unique():
        markers_label_df = markers_df[markers_df.anno_lvl_2==label]
        sns.set_context("talk")
        marker_genes = markers_label_df.gene.tolist()
        scv.pl.umap(spl_adata, color=marker_genes, size=5, fontsize=32, legend_fontsize=32, ncols=ncols,
                    show=False,
                   save="embedding_markers_anno_lvl_2_{s}.{a}.png".format(s="".join(mark_split), a="_".join(label.split("/"))))
    scv.settings.figdir = figdir

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# library(tidyverse)
# library(ggplot2)
# Out:
# R[write to console]: ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# R[write to console]: ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.0     ✔ dplyr   1.0.5
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# R[write to console]: ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# ## Build annotation file
#
# Load annotation file curated by Chenqu/Isaac/Laura

# %%
anno_obs_new = pd.read_csv('../../metadata/manual_annotation/IG_anno_lvl_2_final_clean_051121.csv', index_col=0)

# %%
# Load old annotation file
anno_obs = pd.read_csv(data_dir + "PAN.A01.v01.entire_data_normalised_log.{t}.full_obs.annotated.clean.csv".format(t=timestamp), index_col=0)

# %%
# ## Save 4 legacy
# anno_obs.to_csv(data_dir + "PAN.A01.v01.entire_data_normalised_log.{t}.full_obs.annotated.clean.V2.csv".format(t=timestamp))

# %%
anno_obs.anno_lvl_2_final_clean = anno_obs_new.anno_lvl_2_final_clean.copy()

# %%
anno_obs = anno_obs[['n_counts', 'n_genes', 'file', 'mito', 'doublet_scores',
       'predicted_doublets', 'name', 'uniform_label',
       'uniform_label_expanded_merged', 'uniform_label_lvl0', 'organ',
       'Sample.lanes', 'Sort_id', 'age', 'method', 'donor', 'sex',
       'Processing_method', 'AnnatomicalPart', 'Sample', 'anno_lvl_2_final_clean']]

# %%
all_labels = anno_obs.anno_lvl_2_final_clean.unique()

## clean
clean = {
    ## Myeloid labels
    'LC':'LANGERHANS_CELLS',
    "MONOCYTE_III_CCR2":'MONOCYTE_II_CCR2',
    "MONOCYTE_II_IL1B":"MONOCYTE_III_IL1B",
    'MACROPHAGE_I':"MACROPHAGE_LYVE1_HIGH",
    'MACROPHAGE_II':"MACROPHAGE_IRON_RECYCLING",
    'MACROPHAGE_III':"MACROPHAGE_PROLIFERATING",
    "MACROPHAGE_IV":"MACROPHAGE_MHCII_HIGH",
    'MACROPHAGE_V':"MACROPHAGE_KUPFFER_LIKE",
    'MACROPHAGE_VIII_TREM2':'MACROPHAGE_TREM2',
    'EOSINOPHILBASOPHIL':'EOSINOPHIL_BASOPHIL',
    'MACROPHAGE_VII_ERY':'MACROPHAGE_ERY',
    'MACROPHAGE_VI_PERI':'MACROPHAGE_PERI',
    ## Lymphoid labels
    'TH17': 'TYPE_3_INNATE_T',
    'NK_T': 'TYPE_1_INNATE_T',
    'PRE_PRO_B_CELL':'PRE_PRO_B',
    'DN(P)_T_CELL':'DN(P)_T',
    'DN(early)_T_CELL':'DN(early)_T'
    }

clean_anno = [clean[x] if x in clean.keys() else x for x in anno_obs.anno_lvl_2_final_clean]
clean_anno = ["_".join(x.split("/")) if "/" in x else x for x in clean_anno]
clean_anno = [re.split(" CELLS?$", x)[0] for x in clean_anno]
clean_anno = ["_".join(x.split(" ")) for x in clean_anno]
clean_anno = pd.Series(clean_anno)

anno_obs.anno_lvl_2_final_clean = clean_anno.values.copy()

# %% [markdown]
# #### Update groupings

# %%
## Read annotation groupings
import json
with open('../../metadata/anno_groups.json', 'r') as json_file:
    anno_groups_dict = json.load(json_file)

anno_groups_dict_rev = {x:g for g,a in anno_groups_dict.items() for x in a}

# %%
all_labels = anno_obs.anno_lvl_2_final_clean.unique()

missing_group = [x for x in all_labels if x not in anno_groups_dict_rev.keys()]
for k in missing_group:
    print(k)
    if "FIBROBLAST" in k or "ENDOTHEL" in k or "HEPATOCYTE" in k or "VSMC" in k or "EPITHELIUM" in k or "ENTEROENDOCRINE" in k:
        anno_groups_dict_rev[k] = "STROMA"
    if k=='LMPP_MLP':
        anno_groups_dict_rev[k] = "PROGENITORS"
    if k.endswith("_T"):
        anno_groups_dict_rev[k] = "NK/T CELLS"
    else:
        anno_groups_dict_rev[k] = "MYELOID"

## Remove old labels        
anno_groups_dict_rev = {k:v for k,v in anno_groups_dict_rev.items() if k in all_labels}

ks = list(set([x for x in anno_groups_dict_rev.values()]))
anno_groups_dict = {}
for k1 in ks:
    anno_groups_dict[k1] = [k for k,v in anno_groups_dict_rev.items() if anno_groups_dict_rev[k]==k1]
# Out:
# CYCLING_DC
# MONOCYTE_II_CCR2
# MONOCYTE_III_IL1B
# MACROPHAGE_PROLIFERATING
# MACROPHAGE_MHCII_HIGH
# MACROPHAGE_LYVE1_HIGH
# MACROPHAGE_PERI
# ELP
# LMPP_MLP
# FIBROBLAST_XVII
# TYPE_1_INNATE_T
# LANGERHANS_CELLS
# MACROPHAGE_ERY
# MACROPHAGE_IRON_RECYCLING
# MACROPHAGE_KUPFFER_LIKE
# TYPE_3_INNATE_T
# MACROPHAGE_TREM2

# %%
with open('../../metadata/anno_groups.json', 'w') as outfile:
    json.dump({k:list(v) for k,v in anno_groups_dict.items()}, outfile)

# %% [markdown]
# ## Compare published VS new annotations

# %%
reannotated_df = anno_obs[~anno_obs['uniform_label'].isna()]
annotations_conf_mat = sc.metrics.confusion_matrix("uniform_label", "anno_lvl_2_final_clean", reannotated_df, normalize=False)
anno_tot=sc.metrics.confusion_matrix("uniform_label", "anno_lvl_2_final_clean", anno_obs[~anno_obs['uniform_label'].isna()], normalize=False).sum(0)

# %%
# ## Group labels for plotting
# progenitors_labels = [x for x in reannotated_df.anno_lvl_0_final.unique() if x not in anno_vocabulary["anno_lvl_0"].unique() and x != "nan" and "T CELL" not in x]
# reannotated_df.loc[reannotated_df.anno_lvl_0_final.isin(progenitors_labels),'anno_lvl_0_final'] = "PROGENITORS"
# reannotated_df.loc[reannotated_df.anno_lvl_0_final.isin(['DN(P) T CELL', 'DN(early) T CELL']),'anno_lvl_0_final'] = "NK/T CELLS"

# anno_groups_dict = {}
# for s in reannotated_df["anno_lvl_0_final"].unique():
#     anno_groups_dict[s] = reannotated_df[reannotated_df["anno_lvl_0_final"] == s]["anno_lvl_2_final_clean"].unique()

# %%
def _plot_old_annotation_confusion(anno_group="B CELLS",
                                   min_cells = 5):
    keep_col = anno_groups_dict[anno_group]
    keep_row = annotations_conf_mat.index[np.any(annotations_conf_mat[anno_groups_dict[anno_group]] > min_cells, 1)]
    conf_mat = annotations_conf_mat.loc[keep_row, keep_col].T
    conf_mat = (conf_mat.T/conf_mat.sum(1)).T

    # row_order = conf_mat.max(1).sort_values(ascending=False).index
    row_order = conf_mat.index.sort_values()
    conf_mat = conf_mat.loc[row_order] ## Sort to have some sort of diagonal

    col_order = conf_mat.mean(0).sort_values(ascending=False).index
    conf_mat = conf_mat[col_order] ## Sort to have some sort of diagonal
    sns.heatmap(conf_mat,xticklabels=True, yticklabels=True)

# %%
plt.rcParams["figure.figsize"] = [20,12]
for g in anno_groups_dict.keys():
    _plot_old_annotation_confusion(g)
    plt.xlabel("old annotation");
    plt.ylabel("new annotation");
    plt.savefig(figdir + "oldVSnew_{g}.png".format(g="_".join(g.split("/"))), bbox_inches="tight")
    plt.show()

# %% [markdown]
# ## Organ/age distribution

# %%
org_count_df = anno_obs.groupby(["organ", "anno_lvl_2_final_clean"]).count()['file'].reset_index()
anno_groups_dict_rev = {x:g for g,a in anno_groups_dict.items() for x in a}
org_count_df["anno_group"] = [anno_groups_dict_rev[x] if x in anno_groups_dict_rev.keys() else np.nan for x in org_count_df.anno_lvl_2_final_clean]
org_count_df.loc[org_count_df["anno_group"].isna(), "anno_group"] = "ERYTHROID CELLS"
org_count_df["anno"] = org_count_df["anno_lvl_2_final_clean"]

# %%
org_colors = pd.read_csv("../../metadata/organ_colors.csv", index_col=0)

# %%
age_count_df = anno_obs.groupby(["age", "anno_lvl_2_final_clean"]).count()['file'].reset_index()
anno_groups_dict_rev = {x:g for g,a in anno_groups_dict.items() for x in a}
age_count_df["anno_group"] = [anno_groups_dict_rev[x] if x in anno_groups_dict_rev.keys() else np.nan for x in age_count_df.anno_lvl_2_final_clean]
age_count_df.loc[age_count_df["anno_group"].isna(), "anno_group"] = "ERYTHROID CELLS"
age_count_df["anno"] = age_count_df["anno_lvl_2_final_clean"]

# %%
# %%R -i age_count_df --i figdir -w 800 -h 1000
# age_pl_df <- age_count_df %>%
# #     mutate(anno_group= ifelse(anno=="INTERSTITIAL CELLS OF CAJAL", "STROMA", anno_group)) %>%
# #     mutate(anno_group= ifelse(anno=="LOW_Q_INCONSISTENT", "OTHER", anno_group)) %>%
#     rename(N_cells = file) %>%
#     group_by(anno) %>%
#     mutate(max_age = age[which.max(N_cells)])  %>% ## At which age there are most cells?
#     mutate(min_age = min(age[which(N_cells > 10)]))  %>%
#     ungroup() %>%
#     arrange(- max_age) %>%
#     mutate(anno=factor(anno, levels=unique(anno)))
#
# age_pl_df %>%
#     ggplot(aes(anno, N_cells)) +
#     geom_col(aes(fill=age),position="fill", width=0.8) +
#     coord_flip() +
#     facet_grid(anno_group~., space="free", scales="free") +
#     scale_fill_viridis_c() +
#     theme_bw(base_size=14) +
#     theme(strip.text.y=element_text(angle=0)) +
#     ylab("fraction of cells") + xlab("") +
#     expand_limits(y = 1.2) +
#     geom_text(data=. %>% group_by(anno) %>%
#               summarise(N_cells=sum(N_cells), anno_group=first(anno_group)),
#               hjust=0,
#               y=1.01, aes(label=paste("N =", N_cells))
#              ) +
#     ggsave(paste0(figdir, "age_distribution.pdf"), height=20, width=12) +
#     ggsave(paste0(figdir, "age_distribution.png"), height=20, width=12)

# %%
# %%R -i org_count_df -i org_colors -i figdir -w 800 -h 1000
# org_palette <- setNames(org_colors$color, rownames(org_colors))
# sort_groups <-
#
# org_count_df %>%
#     rename(N_cells = file) %>%
#     mutate(anno=factor(anno, levels=levels(age_pl_df$anno))) %>%
#     mutate(anno=factor(anno, levels=levels(age_pl_df$anno))) %>%
#     ggplot(aes(anno, N_cells)) +
#     geom_col(aes(fill=organ) ,position="fill", width=0.8) +
#     coord_flip() +
#     facet_grid(anno_group~., space="free", scales="free") +
#     scale_fill_manual(values=org_palette) +
#     theme_bw(base_size=14) +
#     theme(strip.text.y=element_text(angle=0)) +
#     ylab("fraction of cells") + xlab("") +
#     expand_limits(y = 1.2) +
#     geom_text(data=. %>% group_by(anno) %>%
#               summarise(N_cells=sum(N_cells), anno_group=first(anno_group)),
#               hjust=0,
#               y=1.01, aes(label=paste("N =", N_cells))
#              ) +
#     ggsave(paste0(figdir, "organ_distribution.pdf"), height=20, width=12) +
#     ggsave(paste0(figdir, "organ_distribution.png"), height=20, width=12)

# %% [markdown]
# ## Save annotations

# %%
anno_obs
# Out:
#                                  n_counts  n_genes            file      mito  \
# FCAImmP7579224-ATTACTCTCGATGAGG   61563.0     6117  FCAImmP7579224  0.036321
# FCAImmP7579224-CAGCCGAGTACATCCA   61511.0     6658  FCAImmP7579224  0.051909
# FCAImmP7579224-TGCTACCTCATGTAGC   54545.0     6485  FCAImmP7579224  0.045284
# FCAImmP7579224-ACGGCCACAAGCTGAG   51992.0     5768  FCAImmP7579224  0.040083
# FCAImmP7579224-CTAATGGCACTGTGTA   51305.0     5492  FCAImmP7579224  0.046467
# ...                                   ...      ...             ...       ...
# FCAImmP7803042-AGTGGGAGTCGACTGC    2015.0      865  FCAImmP7803042  0.032258
# FCAImmP7803042-CCATTCGTCAACACAC    2013.0     1095  FCAImmP7803042  0.034277
# FCAImmP7803042-CGTAGCGAGTGACATA    2011.0      789  FCAImmP7803042  0.073098
# FCAImmP7803042-TGGCCAGCAATGAAAC    2002.0     1041  FCAImmP7803042  0.043457
# FCAImmP7803042-ATTGGACAGGAGTACC    2003.0     1093  FCAImmP7803042  0.056415
#
#                                  doublet_scores predicted_doublets  \
# FCAImmP7579224-ATTACTCTCGATGAGG        0.087221              False
# FCAImmP7579224-CAGCCGAGTACATCCA        0.125320              False
# FCAImmP7579224-TGCTACCTCATGTAGC        0.164087              False
# FCAImmP7579224-ACGGCCACAAGCTGAG        0.092437              False
# FCAImmP7579224-CTAATGGCACTGTGTA        0.176471              False
# ...                                         ...                ...
# FCAImmP7803042-AGTGGGAGTCGACTGC        0.057283              False
# FCAImmP7803042-CCATTCGTCAACACAC        0.019263              False
# FCAImmP7803042-CGTAGCGAGTGACATA        0.098999              False
# FCAImmP7803042-TGGCCAGCAATGAAAC        0.017828              False
# FCAImmP7803042-ATTGGACAGGAGTACC        0.051163              False
#
#                                                          name  uniform_label  \
# FCAImmP7579224-ATTACTCTCGATGAGG  FCAImmP7579224_filtered.h5ad            NaN
# FCAImmP7579224-CAGCCGAGTACATCCA  FCAImmP7579224_filtered.h5ad            NaN
# FCAImmP7579224-TGCTACCTCATGTAGC  FCAImmP7579224_filtered.h5ad            NaN
# FCAImmP7579224-ACGGCCACAAGCTGAG  FCAImmP7579224_filtered.h5ad            NaN
# FCAImmP7579224-CTAATGGCACTGTGTA  FCAImmP7579224_filtered.h5ad            NaN
# ...                                                       ...            ...
# FCAImmP7803042-AGTGGGAGTCGACTGC  FCAImmP7803042_filtered.h5ad            NaN
# FCAImmP7803042-CCATTCGTCAACACAC  FCAImmP7803042_filtered.h5ad     FIBROBLAST
# FCAImmP7803042-CGTAGCGAGTGACATA  FCAImmP7803042_filtered.h5ad            NaN
# FCAImmP7803042-TGGCCAGCAATGAAAC  FCAImmP7803042_filtered.h5ad     FIBROBLAST
# FCAImmP7803042-ATTGGACAGGAGTACC  FCAImmP7803042_filtered.h5ad  KERATINOCYTES
#
#                                 uniform_label_expanded_merged  \
# FCAImmP7579224-ATTACTCTCGATGAGG                           NaN
# FCAImmP7579224-CAGCCGAGTACATCCA                           NaN
# FCAImmP7579224-TGCTACCTCATGTAGC                           NaN
# FCAImmP7579224-ACGGCCACAAGCTGAG                           NaN
# FCAImmP7579224-CTAATGGCACTGTGTA                           NaN
# ...                                                       ...
# FCAImmP7803042-AGTGGGAGTCGACTGC                           NaN
# FCAImmP7803042-CCATTCGTCAACACAC                    FIBROBLAST
# FCAImmP7803042-CGTAGCGAGTGACATA                           NaN
# FCAImmP7803042-TGGCCAGCAATGAAAC                    FIBROBLAST
# FCAImmP7803042-ATTGGACAGGAGTACC                 KERATINOCYTES
#
#                                 uniform_label_lvl0  ...    Sample.lanes  \
# FCAImmP7579224-ATTACTCTCGATGAGG                NaN  ...  FCAImmP7579224
# FCAImmP7579224-CAGCCGAGTACATCCA                NaN  ...  FCAImmP7579224
# FCAImmP7579224-TGCTACCTCATGTAGC                NaN  ...  FCAImmP7579224
# FCAImmP7579224-ACGGCCACAAGCTGAG                NaN  ...  FCAImmP7579224
# FCAImmP7579224-CTAATGGCACTGTGTA                NaN  ...  FCAImmP7579224
# ...                                            ...  ...             ...
# FCAImmP7803042-AGTGGGAGTCGACTGC                NaN  ...  FCAImmP7803042
# FCAImmP7803042-CCATTCGTCAACACAC            STROMAL  ...  FCAImmP7803042
# FCAImmP7803042-CGTAGCGAGTGACATA                NaN  ...  FCAImmP7803042
# FCAImmP7803042-TGGCCAGCAATGAAAC            STROMAL  ...  FCAImmP7803042
# FCAImmP7803042-ATTGGACAGGAGTACC      KERATINOCYTES  ...  FCAImmP7803042
#
#                                 Sort_id age  method donor     sex  \
# FCAImmP7579224-ATTACTCTCGATGAGG   CD45P  12    5GEX   F45  female
# FCAImmP7579224-CAGCCGAGTACATCCA   CD45P  12    5GEX   F45  female
# FCAImmP7579224-TGCTACCTCATGTAGC   CD45P  12    5GEX   F45  female
# FCAImmP7579224-ACGGCCACAAGCTGAG   CD45P  12    5GEX   F45  female
# FCAImmP7579224-CTAATGGCACTGTGTA   CD45P  12    5GEX   F45  female
# ...                                 ...  ..     ...   ...     ...
# FCAImmP7803042-AGTGGGAGTCGACTGC   CD45N  14    5GEX   F51  female
# FCAImmP7803042-CCATTCGTCAACACAC   CD45N  14    5GEX   F51  female
# FCAImmP7803042-CGTAGCGAGTGACATA   CD45N  14    5GEX   F51  female
# FCAImmP7803042-TGGCCAGCAATGAAAC   CD45N  14    5GEX   F51  female
# FCAImmP7803042-ATTGGACAGGAGTACC   CD45N  14    5GEX   F51  female
#
#                                 Processing_method AnnatomicalPart  \
# FCAImmP7579224-ATTACTCTCGATGAGG        Collagnase          Random
# FCAImmP7579224-CAGCCGAGTACATCCA        Collagnase          Random
# FCAImmP7579224-TGCTACCTCATGTAGC        Collagnase          Random
# FCAImmP7579224-ACGGCCACAAGCTGAG        Collagnase          Random
# FCAImmP7579224-CTAATGGCACTGTGTA        Collagnase          Random
# ...                                           ...             ...
# FCAImmP7803042-AGTGGGAGTCGACTGC        Collagnase         unknown
# FCAImmP7803042-CCATTCGTCAACACAC        Collagnase         unknown
# FCAImmP7803042-CGTAGCGAGTGACATA        Collagnase         unknown
# FCAImmP7803042-TGGCCAGCAATGAAAC        Collagnase         unknown
# FCAImmP7803042-ATTGGACAGGAGTACC        Collagnase         unknown
#
#                                                       Sample  \
# FCAImmP7579224-ATTACTCTCGATGAGG  F45_SK_CD45P_FCAImmP7579224
# FCAImmP7579224-CAGCCGAGTACATCCA  F45_SK_CD45P_FCAImmP7579224
# FCAImmP7579224-TGCTACCTCATGTAGC  F45_SK_CD45P_FCAImmP7579224
# FCAImmP7579224-ACGGCCACAAGCTGAG  F45_SK_CD45P_FCAImmP7579224
# FCAImmP7579224-CTAATGGCACTGTGTA  F45_SK_CD45P_FCAImmP7579224
# ...                                                      ...
# FCAImmP7803042-AGTGGGAGTCGACTGC  F51_SK_CD45N_FCAImmP7803042
# FCAImmP7803042-CCATTCGTCAACACAC  F51_SK_CD45N_FCAImmP7803042
# FCAImmP7803042-CGTAGCGAGTGACATA  F51_SK_CD45N_FCAImmP7803042
# FCAImmP7803042-TGGCCAGCAATGAAAC  F51_SK_CD45N_FCAImmP7803042
# FCAImmP7803042-ATTGGACAGGAGTACC  F51_SK_CD45N_FCAImmP7803042
#
#                                 anno_lvl_2_final_clean
# FCAImmP7579224-ATTACTCTCGATGAGG             CYCLING_DC
# FCAImmP7579224-CAGCCGAGTACATCCA              EARLY_ERY
# FCAImmP7579224-TGCTACCTCATGTAGC                PRE_DC2
# FCAImmP7579224-ACGGCCACAAGCTGAG       MONOCYTE_II_CCR2
# FCAImmP7579224-CTAATGGCACTGTGTA            LARGE_PRE_B
# ...                                                ...
# FCAImmP7803042-AGTGGGAGTCGACTGC        FIBROBLAST_XIII
# FCAImmP7803042-CCATTCGTCAACACAC           FIBROBLAST_V
# FCAImmP7803042-CGTAGCGAGTGACATA           FIBROBLAST_I
# FCAImmP7803042-TGGCCAGCAATGAAAC          FIBROBLAST_IV
# FCAImmP7803042-ATTGGACAGGAGTACC           KERATINOCYTE
#
# [908178 rows x 21 columns]

# %%
anno_obs.to_csv(data_dir + "PAN.A01.v01.entire_data_normalised_log.{t}.full_obs.annotated.clean.csv".format(t=timestamp))

# %%
data_dir + "PAN.A01.v01.entire_data_normalised_log.{t}.full_obs.annotated.clean.csv".format(t=timestamp)
# Out:
# '/nfs/team205/ed6/data/Fetal_immune/PAN.A01.v01.entire_data_normalised_log.20210429.full_obs.annotated.clean.csv'

# %%
## Save file for lvl1 groupings 
anno_lvl_0_df = pd.DataFrame([(x,y) for x,y in anno_groups_dict_rev.items()])
anno_lvl_0_df.columns = ['anno_lvl_2_final_clean', "anno_lvl_0"]
anno_lvl_0_df.to_csv('/home/jovyan/mount/gdrive/Pan_fetal/annotations/annotation_terms_20211106.csv')

# %% [markdown]
# ---

# %%
progenitors_dict = {
    "B CELLS":["PRO_B", 'PRE_PRO_B','LATE_PRO_B']
}

# %%
prog_anno_df = anno_obs[anno_obs.anno_lvl_2_final_clean.isin(progenitors_dict["B CELLS"])][["anno_lvl_2_final_clean", "organ", 'uniform_label']]

for o in prog_anno_df['organ'].unique():
    print(o)
    print(prog_anno_df[prog_anno_df['organ'] == o].value_counts('uniform_label'))
# prog_anno_df[prog_anno_df['organ'] == 'SP'].value_counts('uniform_label')
# Out:
# SK
# uniform_label
# B CELL    362
# dtype: int64
# SP
# uniform_label
# PRE PRO B CELL           250
# PRO B CELL               189
# B CELL                     6
# MACROPHAGE                 5
# MYOFIBROBLAST              4
# NK                         3
# NK T                       2
# NEUTROPHIL PROGENITOR      2
# MID ERYTHROID              1
# MEMP                       1
# HSC                        1
# ENDOTHELIAL CELL           1
# EARLY MK                   1
# dtype: int64
# YS
# uniform_label
# MACROPHAGE             22
# LYMPHOID PROGENITOR    19
# EARLY ERYTHROID         2
# MEMP                    1
# MAST CELL               1
# dtype: int64
# LI
# uniform_label
# PRO B CELL                661
# PRE B CELL                211
# ELP                       151
# B CELL                     28
# EARLY ERYTHROID/T CELL      4
# PDC PROGENITOR              3
# PDC PRECURSOR               1
# dtype: int64
# TH
# uniform_label
# PRE PRO B CELL         126
# DN T CELL               19
# LYMPHOID PROGENITOR     14
# B CELL                   3
# PDC                      2
# DP T CELL                2
# SP T CELL                1
# dtype: int64
# GU
# Series([], dtype: int64)
# BM
# uniform_label
# PRE PRO B CELL            4619
# PRO B CELL                2373
# ELP                       1019
# PRE B CELL                 163
# MONOCYTE                    57
# B CELL                      34
# PROMONOCYTE                 30
# EARLY ERYTHROID             16
# NEUTROPHIL                  14
# MYELOCYTE                   13
# EARLY MK                    11
# MOP                         10
# NK                           7
# PDC PROGENITOR               6
# MACROPHAGE                   6
# PDC                          5
# MEGAKARYOCYTE                5
# DC                           4
# GMP                          4
# LMPP                         4
# PROMYELOCYTE                 4
# OSTEOCLAST                   4
# NK T                         2
# DC PRECURSOR                 2
# CMP                          2
# BASOPHIL                     2
# HSC                          1
# EOSINOPHIL                   1
# EO/BASO/MAST PRECURSOR       1
# MPP MYELOID                  1
# MYELOID DC PROGENITOR        1
# TREG                         1
# dtype: int64
# KI
# uniform_label
# B CELL    58
# ILC        1
# dtype: int64
# MLN
# Series([], dtype: int64)

# %%
split="MYELOID_V2"
spl_adata = sc.read_h5ad(data_dir + 'PAN.A01.v01.entire_data_normalised_log.{t}.{s}.embedding.h5ad'.format(t=timestamp, s=split))
spl_adata = spl_adata[~spl_adata.obs_names.isin(mat_barcodes)]a

# %%
spl_adata.obs['annotation'] = anno_obs_new.loc[spl_adata.obs_names]['anno_lvl_2_final_clean_v3']
# Out:
# Trying to set attribute `.obs` of view, copying.

# %%
sc.pl.umap(spl_adata, color=['annotation','leiden_150'],size=20, legend_loc="on data")

# %%
sc.pl.umap(spl_adata, color=['leiden_150'], groups=[23], size=20)

# %%
spl_adata.obs[spl_adata.obs["leiden_150"]==23].annotation.value_counts()
# Out:
# DC3                       1266
# DC2                        593
# MONOCYTE_III_CCR2          370
# MACROPHAGE                 238
# MONOCYTE_I_CXCR4           140
# MACROPHAGE_IV              108
# CYCLING_DC2                 43
# DC1                         27
# DC_PROGENITOR               11
# LC                           9
# MONOCYTE_II_IL1B             5
# AS_DC                        3
# MACROPHAGE_V                 2
# PDC                          1
# PROMYELOCYTE                 1
# CYCLING_PDC                  0
# HSC_MPP                      0
# CYCLING_DC3                  0
# CMP                          0
# EARLY_MK                     0
# ELP                          0
# EOSINOPHILBASOPHIL           0
# FIBROBLAST                   0
# GMP                          0
# MACROPHAGE_I                 0
# LOW_QUALITY_MACROPHAGE       0
# PROMONOCYTE                  0
# MACROPHAGE_II                0
# MACROPHAGE_III               0
# MAST_CELL                    0
# MEMP                         0
# MICROGLIA_P2RY12             0
# MIGRATORY_DC1                0
# MIGRATORY_DC2                0
# MOP                          0
# MYELOCYTE                    0
# NEUTROPHIL                   0
# OSTEOCLAST                   0
# PRE_DC2                      0
# ACTIVATED_DC1                0
# Name: annotation, dtype: int64

# %% [markdown]
# ---
